# %% [markdown]
# # COMPOSITE VOICE INSTABILITY INDEX (JITTER + SHIMMER)

# %% [markdown]
# ## $ Jitter = \frac{1}{N-1} Σ_{i=1}^{N-1} |T_i - T_{i+1}| / (\frac{1}{N} Σ_{i=1}^{N} T_i) $
#
# ## $ Shimmer = \frac{1}{N-1} Σ_{i=1}^{N-1} |A_i - A_{i+1}| / (\frac{1}{N} Σ_{i=1}^{N} A_i) $

# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt

# %%
def compute_jitter_shimmer(audio, sr, f0_min=75, f0_max=300):

    # pitch using pyin

    f0, voiced_flag, _= librosa.pyin(audio, fmin=f0_min, fmax=f0_max, sr)

    # filter voiced frames

    f0_voiced = f0[voic]
